# %%
import pandas as pd
df=pd.read_csv("C:/Users/Sithany/Downloads/titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
sns.boxplot(data=df,x='Sex',y='Survived')
plt.show()

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
inputs=df.drop(['Survived','PassengerId','Name','SibSp','Parch','Ticket','Embarked','Cabin'],axis='columns')
target=df['Survived']

# %%
inputs
# Out:
#      Pclass     Sex   Age     Fare
# 0         3    male  22.0   7.2500
# 1         1  female  38.0  71.2833
# 2         3  female  26.0   7.9250
# 3         1  female  35.0  53.1000
# 4         3    male  35.0   8.0500
# ..      ...     ...   ...      ...
# 886       2    male  27.0  13.0000
# 887       1  female  19.0  30.0000
# 888       3  female   NaN  23.4500
# 889       1    male  26.0  30.0000
# 890       3    male  32.0   7.7500
#
# [891 rows x 4 columns]

# %%
inputs.isna().sum()
# Out:
# Pclass      0
# Sex         0
# Age       177
# Fare        0
# dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.histplot(df['Age'],bins=80)
plt.show()

# %%
inputs['Age'].median()
# Out:
# 28.0

# %%
dff=inputs.fillna(inputs['Age'].median())

# %%
dff.isna().sum()
# Out:
# Pclass    0
# Sex       0
# Age       0
# Fare      0
# dtype: int64

# %%
dff
# Out:
#      Pclass     Sex   Age     Fare
# 0         3    male  22.0   7.2500
# 1         1  female  38.0  71.2833
# 2         3  female  26.0   7.9250
# 3         1  female  35.0  53.1000
# 4         3    male  35.0   8.0500
# ..      ...     ...   ...      ...
# 886       2    male  27.0  13.0000
# 887       1  female  19.0  30.0000
# 888       3  female  28.0  23.4500
# 889       1    male  26.0  30.0000
# 890       3    male  32.0   7.7500
#
# [891 rows x 4 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
dff['sex']=le.fit_transform(dff['Sex'])
dff.head()
# Out:
#    Pclass     Sex   Age     Fare  sex
# 0       3    male  22.0   7.2500    1
# 1       1  female  38.0  71.2833    0
# 2       3  female  26.0   7.9250    0
# 3       1  female  35.0  53.1000    0
# 4       3    male  35.0   8.0500    1

# %%
dff.columns
# Out:
# Index(['Pclass', 'Sex', 'Age', 'Fare', 'sex'], dtype='object')

# %%
data=dff.drop('Sex',axis='columns')
data.head()
# Out:
#    Pclass   Age     Fare  sex
# 0       3  22.0   7.2500    1
# 1       1  38.0  71.2833    0
# 2       3  26.0   7.9250    0
# 3       1  35.0  53.1000    0
# 4       3  35.0   8.0500    1

# %%
from sklearn.model_selection import train_test_split

# %%
data_train,data_test,target_train,target_test=train_test_split(data,target,test_size=0.2)

# %%
data_train
# Out:
#      Pclass   Age     Fare  sex
# 223       3  28.0   7.8958    1
# 880       2  25.0  26.0000    0
# 596       2  28.0  33.0000    0
# 855       3  18.0   9.3500    0
# 420       3  28.0   7.8958    1
# ..      ...   ...      ...  ...
# 517       3  28.0  24.1500    1
# 94        3  59.0   7.2500    1
# 433       3  17.0   7.1250    1
# 397       2  46.0  26.0000    1
# 58        2   5.0  27.7500    0
#
# [712 rows x 4 columns]

# %%
target_test.shape
# Out:
# (179,)

# %%
data_test
# Out:
#      Pclass   Age     Fare  sex
# 84        2  17.0  10.5000    0
# 357       2  38.0  13.0000    0
# 82        3  28.0   7.7875    0
# 709       3  28.0  15.2458    1
# 361       2  29.0  27.7208    1
# ..      ...   ...      ...  ...
# 154       3  28.0   7.3125    1
# 702       3  18.0  14.4542    0
# 571       1  53.0  51.4792    0
# 143       3  19.0   6.7500    1
# 622       3  20.0  15.7417    1
#
# [179 rows x 4 columns]

# %%
from sklearn import tree

# %%
model=tree.DecisionTreeClassifier()

# %%
model.fit(data_train,target_train)
# Out:
# DecisionTreeClassifier()

# %%
target_predict=model.predict(data_test)

# %%
from sklearn.metrics import accuracy_score

# %%
ac
