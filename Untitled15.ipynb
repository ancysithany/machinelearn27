# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as ps

# %%
df=sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# WARNING:root:Quickchart encountered unexpected dtypes in columns: "(['class', 'deck'],)"
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
# ...

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.shape
# Out:
# (891, 15)

# %%
df.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df[['age']].isna()
# Out:
#        age
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# ..     ...
# 886  False
# 887  False
# 888   True
# 889  False
# 890  False
#
# [891 rows x 1 columns]

# %%
df[['age']].median()
# Out:
# age    28.0
# dtype: float64

# %%
dff=df['age'].fillna(df['age'].mode())

# %%
dff
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    28.0
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
df['age'].isna().sum()
# Out:
# 0

# %%
new_df = df.drop('deck', axis=1)

# %%
new_df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  28.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
new_df.duplicated().sum()
# Out:
# 116

# %% [markdown]
# returns if there is any duplicated rows

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          891 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  embark_town  889 non-null    object
#  12  alive        891 non-null    object
#  13  alone        891 non-null    bool
# dtypes: bool(2), category(1), float64(2), int64(4), object(5)
# memory usage: 79.4+ KB

# %%
new_df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.361582    0.523008    0.381594   32.204208
# std      0.486592    0.836071   13.019697    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# describe only works for integers and float values

# %%
agee=new_df.loc[new_df['age'].idxmin()]
agee
# Out:
# survived               1
# pclass                 3
# sex                 male
# age                 0.42
# sibsp                  0
# parch                  1
# fare              8.5167
# embarked               C
# class              Third
# who                child
# adult_male         False
# embark_town    Cherbourg
# alive                yes
# alone              False
# Name: 803, dtype: object

# %% [markdown]
# describing categorical value

# %%
new_df.describe(include='category')
# Out:
#         class
# count     891
# unique      3
# top     Third
# freq      491
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_28.groupby('class').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
new_df.describe(include='all')
# Out:
#           survived      pclass   sex         age       sibsp       parch  \
# count   891.000000  891.000000   891  891.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.361582    0.523008    0.381594
# std       0.486592    0.836071   NaN   13.019697    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   22.000000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   35.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               fare embarked  class  who adult_male  embark_town alive alone
# ...

# %%
plt.figure(figsize=(10,10))
sns.histplot(df['age'],bins=80)
plt.show()

# %%
df.hist(layout=(1,6),figsize=(10,10))
plt.show()

# %%
sns.boxplot(data=df,y='age')
plt.show()

# %%
sns.boxenplot(data=df,y='age')
plt.show()

# %%
sns.violinplot(data=df,y='age')
plt.show()

# %%
sns.scatterplot(data=df,x='age',y='fare')
plt.show()

# %%
sns.scatterplot(data=df,x='age',y='fare',hue='sex')
plt.show()

# %%
sns.pairplot(df[['age','fare','sex']])
plt.show()

# %%
sns.pairplot(df[['age','sibsp','parch','fare']])
plt.show()

# %%
corre=df[['age','sibsp','parch','fare']].corr()
corre
# Out:
#             age     sibsp     parch      fare
# age    1.000000 -0.233296 -0.172482  0.096688
# sibsp -0.233296  1.000000  0.414838  0.159651
# parch -0.172482  0.414838  1.000000  0.216225
# fare   0.096688  0.159651  0.216225  1.000000

# %%
sns.heatmap(corre,annot=True)  #annotation is to print the values in the heatmap
plt.show()

# %%
df['embark_town'].value_counts()
# Out:
# embark_town
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: count, dtype: int64

# %%
sns.barplot(x=df['embark_town'].value_counts().index,y=df['embark_town'].value_counts().values)
plt.show()
